# %%
import json
import urllib
import os
import csv
import pandas as pd

# %% [markdown]
# # 0. Preliminary step to get the dataset

# %%
#if the filtered documents file has already been generated by previously running the notebook
# upload the file in notebook env and call it here
# run the cell that mounts google drive if you want to save output there
# then set the output folder and run the output folder cell
# after G Drive is mounted and the output folder set, go directly to step 1.3 without running the cells in between
# corpus_df = pd.read_csv('documents_list.csv')

# %% [markdown]
# Getting data from sharable google drive folder

# %%
# link to folder: https://drive.google.com/drive/folders/18TjiltRr8CFlx0aPcLsnKBr5iyeiQxWc?usp=sharing
# upload data folder to your drive root folder 'My Drive' (It is the default folder).

# %%
# connect your drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')
# after running this cell, open the url that displays below from your gmail account
# copy the code that is displayed 
# paste the code into the cell below when prompted and then press enter
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
folder_path = '/content/drive/My Drive/data_tm_workflow/'

# %%
# set the output folder in the drive (the csv files with the results of the process will be downloaded there)
# first create the empty folder in the drive
output_folder = '/content/drive/My Drive/output_tm_tfidf'

# %% [markdown]
# # 1. Data preparation

# %% [markdown]
# ## 1.1. Creating data frame
# A dataframe is first created to keep the documents at their initial state, and the name of each file

# %%
files_list = os.listdir(folder_path)

# %%
#insert file names into a df
sources = pd.DataFrame(files_list, columns=['file_name'])

# %% [markdown]
# ## 1.2. Adding columns for dates, publications and filtering dataset

# %% [markdown]
# ### 1.2.1. dates, publications

# %%
import re

# %%
# get publication ref from file name
def get_ref(file):
  ref_match = re.findall(r'(\w+\d+)_\d{4}-\d{2}-\d{2}_',file)
  return ref_match[0]

# get date from file name
def get_date(file):
  date_match = re.findall(r'_(\d{4}-\d{2}-\d{2})_',file)
  return date_match[0]

# get year from file name
def get_year(file):
  year_match = re.findall(r'_(\d{4})-\d{2}-\d{2}_',file)
  return year_match[0]

# get month from file name
def get_month(file):
  month_match = re.findall(r'_\d{4}-(\d{2})-\d{2}_',file)
  return month_match[0]

# get day from file name
def get_day(file):
  month_match = re.findall(r'_\d{4}-\d{2}-(\d{2})_',file)
  return month_match[0]

# %%
sources['date'] = sources['file_name'].apply(lambda x: get_date(x))
sources['year'] = sources['file_name'].apply(lambda x: get_year(x))
sources['month'] = sources['file_name'].apply(lambda x: get_month(x))
sources['day'] = sources['file_name'].apply(lambda x: get_day(x))
sources['publication'] = sources['file_name'].apply(lambda x: get_ref(x))

# %%
# add publication names
def get_pub_name(pub_number):
    if (pub_number == 'sn85066408'):
        return 'L\'Italia'
    elif (pub_number == '2012271201'):
        return 'Cronaca Sovversiva'

# %%
sources['publication_name'] = sources['publication'].apply(lambda x: get_pub_name(x))

# %% [markdown]
# ### 1.2.2. Filtering

# %%
import datetime
from datetime import timedelta, date

# %%
# Start from 06.06.1903 and finish 01.05.1919
date_ref_1 = date(1903,6,6)
date_ref_2 = date(1919,5,1)

# %%
def filter_by_date(date_item,date_ref_1,date_ref_2):
    year = re.findall(r'(\d{4})-\d{2}-\d{2}',date_item)[0]
    month = re.findall(r'\d{4}-(\d{2})-\d{2}',date_item)[0]
    day = re.findall(r'\d{4}-\d{2}-(\d{2})',date_item)[0]
    file_date = date(int(year),int(month),int(day))
    if (date_ref_1 <= file_date <= date_ref_2):
        return 'included'
    else:
        return 'not included'

# %%
sources['status'] = sources['date'].apply(lambda x: filter_by_date(x,date_ref_1,date_ref_2))

# %%
# variable containing the filtered documents
corpus_df = sources[sources['status'] == 'included'].copy().reset_index()

# %% [markdown]
# ### 1.2.3 Adding text content

# %%
# read the content of the text files
def readTxtContent(fileName):
  with open(folder_path + fileName, 'r') as file:
    return ' ' + file.read().replace('\n', ' ') + ' '

# %%
# add a column to the dataframe containing file content
corpus_df['file_content'] = corpus_df['file_name'].apply(lambda x: readTxtContent(x))

# %%
corpus_df.to_csv(output_folder + '/documents_list.csv')

# %% [markdown]
# ## 1.3 Removing stop words, punctuation, short words

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# add tokenized documents in dataframe
corpus_df['tokens'] = corpus_df['file_content'].apply(lambda x: nltk.word_tokenize(x))

# %%
# possible user options:
# .isalnum() to removes tokens that include numbers
# .isalpha() to remove all tokens that contain more than letters (punctuation and numbers)
# .isdecimal() to remove tokens that contain only decimals
# .isdigit() to remove tokens that contain only digits

# add new column in df with processed tokens (here: keeping only alpha tokens longer than 3 characters + lowercasing)
corpus_df['doc_prep'] = corpus_df['tokens'].apply(lambda x: [w.lower() for w in x if (w.isalpha() and len(w) > 2 )])

# %%
# link to custom stop words: https://drive.google.com/file/d/1VVfW6AKPbb7_fICOG73lEgkXmmZ6BkpC/view?usp=sharing
# Upload stop words list into Colab files before proceeding with the next cells

# %%
from nltk.corpus import stopwords
ital_stopwords = stopwords.words('italian')
en_stopwords = stopwords.words('english')

# %%
stop_words = pd.read_csv('stop_words.csv')

# %%
stopwords = stop_words['stopword'].values.tolist()

# %%
# add english stop words list to custom stopwords 
stopwords.extend(en_stopwords)

# %%
# to append list of words added by user: ital_stopwords.extend(user_input)
# to remove words: ital_stopwords.remove(user_input)

# %%
# add column with tokenized documents without sw
corpus_df['doc_prep_nostop'] = corpus_df['doc_prep'].apply(lambda x: [w for w in x if not w in stopwords])

# %%
corpus_df['doc_prep_nostop']
# Out:
# 0      [nura, dtfip, verrmo, assioma, auanto, barba, ...
# 1      [saturday, january, barre, vermont, sabato, ge...
# 2      [annj, xii, iodio, mite, umberto, santo, costi...
# 3      [vili, entered, brusco, svolto, storia, partit...
# 4      [scoi, ietti, lez, actf, àttof, coij, peri, it...
#                              ...
# 766    [ionn, imperversa, giungono, spiaggie, patria,...
# 767    [ass, ittc, ass, tìii, eie, alt, sss, lynn, au...
# 768    [num, xii, magnifico, pertinacia, levato, pean...
# 769    [ann, rhe, fcr, rivo, ragioni, economiche, sfa...
# 770    [newspapet, objection, anvo, nura, mmmmmmm, an...
# Name: doc_prep_nostop, Length: 771, dtype: object

# %%
# set the variable to use for topic modelling (if no further options are used)
corpus_model = corpus_df['doc_prep_nostop']

# %%
# save the data after pre-processing in the output folder for verification of pre-processing steps
# corpus_df.to_csv(output_folder + '/corpus_df.csv')
corpus_df.to_csv(output_folder + '/corpus_df.csv')

# %% [markdown]
# ## 1.4 Lemmatize

# %%
# Lemmatization is available in multiple languages in Spacy and not in NLTK (only English)
# With Spacy, lemmatization is available for 10 languages. There's also a multi-language option that
# should be tested if additional languages are needed

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.7.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (49.1.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)

# %%
# !python3 -m spacy download it_core_news_sm
# Out:
# Requirement already satisfied: it_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-2.2.5/it_core_news_sm-2.2.5.tar.gz#egg=it_core_news_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from it_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (49.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (0.7.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.18.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->it_core_news_sm==2.2.5) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->it_core_news_sm==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('it_core_news_sm')

# %%
import it_core_news_sm
it_nlp = it_core_news_sm.load(disable=['tagger', 'parser', 'ner'])

# %%
# lemmatization function
def lemmatize(doc):
  lemmatized_doc = []
  for w in doc:
    w_lemma = [token.lemma_ for token in it_nlp(w)]
    lemmatized_doc.append(w_lemma[0])
  return lemmatized_doc

# %%
# add column with lemmatized tokens - directly from the tokens as preprocessing has already been done
corpus_df['doc_lemmatized'] = corpus_df['doc_prep_nostop'].apply(lambda x: lemmatize(x))

# %%
# variable with lemmatized tokens
lemmatized_corpus = corpus_df['doc_lemmatized']
# the lemmatized version is not used in this example

# %% [markdown]
# # 2. Topics with LDA and TFIDF

# %%
#Gensim installation
! pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.1.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.14.22)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.23.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.22 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.17.22)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.10)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.22->boto3->smart-open>=1.2.1->gensim) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.22->boto3->smart-open>=1.2.1->gensim) (2.8.1)

# %%
import gensim
from gensim.test.utils import common_corpus, common_dictionary
from gensim import corpora, models

# %% [markdown]
# ## 2.1 Preliminary steps to run LDA and TFIDF

# %% [markdown]
# ### 2.1.1 Creating the dictionary, optional filtering of extreme values

# %%
# if you use lemmatized version replace "corpus_model" by lemmatized_corpus
id2word = corpora.Dictionary(corpus_model)

# %%
id2word.filter_extremes(no_below=5)

# %% [markdown]
# ### 2.1.2 Bag of words

# %%
corpus = [id2word.doc2bow(text) for text in corpus_model]

# %% [markdown]
# ### 2.1.3 TFIDF

# %%
tfidf = models.TfidfModel(corpus)
corpus = tfidf[corpus]

# %% [markdown]
# ## 2.2 LDA

# %% [markdown]
# ### 2.2.1. Option 1: Train a model without coherence calculation

# %%
# set the nr of topics
num_topics = 7

# %%
# faster preset (hypothetically less accurate)
# model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, eval_every = None)
# slower preset (hypothetically more accurate)
# model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, chunksize=1000, iterations = 200, passes = 10, eval_every = None)
# slowest preset (hypothetically even more accurate)
model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, chunksize=2000, iterations = 400, passes = 20, eval_every = None)

# %%
topic_print_model = model.print_topics(num_words=30)

# %%
df_topic_print_model = pd.DataFrame(topic_print_model, columns=['topic_id','words'])

# %%
df_topic_print_model.to_csv(output_folder +'/topics_without_coherence.csv')

# %% [markdown]
# ### 2.2.2. Option 2: Train models and compute coherence

# %% [markdown]
# Topic Coherence measures score of a single topic by measuring the degree of semantic similarity between high scoring words in the topic. https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0

# %%
from gensim.models.coherencemodel import CoherenceModel

# %%
# %%capture
topics_nr = []
coherence_values_gensim = []
models = []
models_idx = [x for x in range(3,20)]
for num_topics in range(3, 20):
  # fastest processing time preset (hypothetically less accurate)
  # model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, eval_every = None)
  # slower processing time preset (hypothetically more accurate)
  # model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, chunksize=1000, iterations = 200, passes = 10, eval_every = None)
  # slowest processing time preset approx 35min for 700 short docs (hypothetically even more accurate)
  model = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=id2word, num_topics=num_topics, chunksize=2000, iterations = 400, passes = 20, eval_every = None)
  models.append(model)
  coherencemodel = CoherenceModel(model=model, texts=corpus_model, dictionary=id2word, coherence='c_v')
  coherence_value = coherencemodel.get_coherence()
  coherence_values_gensim.append(coherence_value)
  topics_nr.append(str(num_topics))

# %%
for i in range(len(topics_nr)):
  print("Num Topics =", topics_nr[i], " has Coherence Value of", round(coherence_values_gensim[i],4))
# Out:
# Num Topics = 3  has Coherence Value of 0.312
# Num Topics = 4  has Coherence Value of 0.3235
# Num Topics = 5  has Coherence Value of 0.3504
# Num Topics = 6  has Coherence Value of 0.3404
# Num Topics = 7  has Coherence Value of 0.4406
# Num Topics = 8  has Coherence Value of 0.5513
# Num Topics = 9  has Coherence Value of 0.5299
# Num Topics = 10  has Coherence Value of 0.6044
# Num Topics = 11  has Coherence Value of 0.5843
# Num Topics = 12  has Coherence Value of 0.5897
# Num Topics = 13  has Coherence Value of 0.595
# Num Topics = 14  has Coherence Value of 0.5899
# Num Topics = 15  has Coherence Value of 0.6168
# Num Topics = 16  has Coherence Value of 0.6261
# Num Topics = 17  has Coherence Value of 0.5873
# Num Topics = 18  has Coherence Value of 0.6423
# Num Topics = 19  has Coherence Value of 0.5925

# %%
df_coherence = pd.DataFrame(topics_nr, columns=['topic_id'])

# %%
df_coherence['topic_coherence'] = coherence_values_gensim

# %%
# df_coherence.to_csv(output_folder +'/coherence_values.csv')
df_coherence.to_csv(output_folder + '/coherence_values.csv')

# %%
# Visualize coherence scores
import matplotlib.pyplot as plt

# %%
plt.plot(topics_nr, coherence_values_gensim)

# %%
# print topics for the different numbers of topics
for i in range(len(models_idx)):
  numtopics = models_idx[i]
  print('nr of topics: {}'.format(numtopics))
  model = models[i]
  topic_print = model.print_topics(num_words=30)
  df_topic_print = pd.DataFrame(topic_print, columns=['topic_id','words'])
  print(df_topic_print['words'])
  filename = '{}/num_topics_{}.csv'.format(output_folder,numtopics)
  df_topic_print.to_csv(filename)
# Out:
# nr of topics: 3
# 0    0.000*"acciarito" + 0.000*"ferrer" + 0.000*"di...
# 1    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 2    0.000*"roosevelt" + 0.000*"sciopero" + 0.000*"...
# Name: words, dtype: object
# nr of topics: 4
# 0    0.000*"partito" + 0.000*"socialista" + 0.000*"...
# 1    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 2    0.000*"ferrer" + 0.000*"dio" + 0.000*"congress...
# 3    0.000*"contadini" + 0.000*"satana" + 0.000*"sc...
# Name: words, dtype: object
# nr of topics: 5
# 0    0.000*"sonnino" + 0.000*"parlamentare" + 0.000...
# 1    0.000*"partito" + 0.000*"satana" + 0.000*"roos...
# 2    0.000*"ferrer" + 0.000*"pressed" + 0.000*"oper...
# 3    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 4    0.000*"pouren" + 0.000*"polignani" + 0.000*"go...
# Name: words, dtype: object
# nr of topics: 6
# 0    0.000*"congresso" + 0.000*"wilson" + 0.000*"ro...
# 1    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 2    0.000*"cunha" + 0.000*"mooney" + 0.000*"ficker...
# 3    0.000*"galleani" + 0.000*"ferrerò" + 0.000*"sc...
# 4    0.000*"bocchini" + 0.000*"long" + 0.000*"falls...
# 5    0.000*"ferri" + 0.000*"confederazione" + 0.000...
# Name: words, dtype: object
# nr of topics: 7
# 0    0.000*"scalpellini" + 0.000*"duncan" + 0.000*"...
# 1    0.000*"ferrer" + 0.000*"bakounine" + 0.000*"co...
# 2    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 3    0.000*"long" + 0.000*"partito" + 0.000*"bocchi...
# 4    0.000*"pouren" + 0.000*"jan" + 0.000*"janoff" ...
# 5    0.000*"sessuale" + 0.000*"duma" + 0.000*"solle...
# 6    0.000*"robert" + 0.000*"dagoes" + 0.000*"crede...
# Name: words, dtype: object
# nr of topics: 8
# 0    0.000*"cordage" + 0.000*"plymouth" + 0.000*"pa...
# 1    0.000*"sonnino" + 0.000*"calumet" + 0.000*"sia...
# 2    0.000*"pouren" + 0.000*"janoff" + 0.000*"jan" ...
# 3    0.000*"sciopero" + 0.000*"partito" + 0.000*"so...
# 4    0.000*"ferrovieri" + 0.000*"gettate" + 0.000*"...
# 5    0.000*"terroristi" + 0.000*"moret" + 0.000*"ba...
# 6    0.000*"duma" + 0.000*"robertson" + 0.000*"mich...
# 7    0.000*"versagliesi" + 0.000*"panie" + 0.000*"g...
# Name: words, dtype: object
# nr of topics: 9
# 0    0.000*"carco" + 0.000*"pressed" + 0.000*"kees"...
# 1    0.000*"angelelli" + 0.000*"dagoes" + 0.000*"ko...
# 2    0.000*"sognatori" + 0.000*"diciasette" + 0.000...
# 3    0.000*"moral" + 0.000*"masetti" + 0.000*"getta...
# 4    0.000*"good" + 0.000*"panie" + 0.000*"get" + 0...
# 5    0.000*"iglesias" + 0.000*"referendum" + 0.000*...
# 6    0.001*"sciopero" + 0.001*"partito" + 0.000*"so...
# 7    0.000*"biribi" + 0.000*"prampolini" + 0.000*"s...
# 8    0.001*"diaz" + 0.001*"kotoku" + 0.001*"madero"...
# Name: words, dtype: object
# nr of topics: 10
# 0    0.000*"carco" + 0.000*"kees" + 0.000*"pressed"...
# 1    0.000*"polignani" + 0.000*"abarno" + 0.000*"sa...
# 2    0.001*"kotoku" + 0.001*"pouren" + 0.001*"sinda...
# 3    0.000*"cunha" + 0.000*"pablo" + 0.000*"iglesia...
# 4    0.000*"montpelier" + 0.000*"covelli" + 0.000*"...
# 5    0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 6    0.000*"meunier" + 0.000*"sonnino" + 0.000*"udi...
# 7    0.000*"moral" + 0.000*"satana" + 0.000*"good" ...
# 8    0.000*"dagoes" + 0.000*"calumet" + 0.000*"tire...
# 9    0.000*"vigilanti" + 0.000*"german" + 0.000*"fi...
# Name: words, dtype: object
# nr of topics: 11
# 0     0.000*"turner" + 0.000*"dante" + 0.000*"schnei...
# 1     0.000*"udite" + 0.000*"diffusi" + 0.000*"ferna...
# 2     0.001*"kotoku" + 0.001*"thiers" + 0.001*"tolst...
# 3     0.001*"bocchini" + 0.001*"diaz" + 0.001*"steel...
# 4     0.001*"arabi" + 0.001*"cunha" + 0.001*"ludlow"...
# 5     0.001*"polignani" + 0.001*"abarno" + 0.000*"st...
# 6     0.000*"carlos" + 0.000*"pià" + 0.000*"michel" ...
# 7     0.000*"robertson" + 0.000*"braganza" + 0.000*"...
# 8     0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 9     0.000*"saverio" + 0.000*"metallurgici" + 0.000...
# 10    0.000*"therefore" + 0.000*"circulation" + 0.00...
# Name: words, dtype: object
# nr of topics: 12
# 0     0.001*"ettor" + 0.001*"giovannitti" + 0.001*"p...
# 1     0.001*"polignani" + 0.001*"abarno" + 0.000*"am...
# 2     0.000*"gettate" + 0.000*"sott" + 0.000*"feudal...
# 3     0.000*"siamesi" + 0.000*"semplicisti" + 0.000*...
# 4     0.000*"merlino" + 0.000*"saverio" + 0.000*"vie...
# 5     0.000*"good" + 0.000*"messina" + 0.000*"sollev...
# 6     0.000*"colajanni" + 0.000*"cantine" + 0.000*"p...
# 7     0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 8     0.001*"bocchini" + 0.001*"pouren" + 0.001*"fal...
# 9     0.001*"goldman" + 0.001*"soglia" + 0.001*"trib...
# 10    0.000*"marchi" + 0.000*"appresi" + 0.000*"ange...
# 11    0.000*"pablo" + 0.000*"robertson" + 0.000*"lie...
# Name: words, dtype: object
# nr of topics: 13
# 0     0.000*"sessuale" + 0.000*"calumet" + 0.000*"co...
# 1     0.001*"novella" + 0.001*"formazione" + 0.001*"...
# 2     0.001*"donna" + 0.001*"galleani" + 0.001*"bako...
# 3     0.001*"therefore" + 0.000*"circulation" + 0.00...
# 4     0.000*"gettate" + 0.000*"ferrerò" + 0.000*"vau...
# 5     0.000*"covelli" + 0.000*"saverio" + 0.000*"mor...
# 6     0.000*"hell" + 0.000*"spokane" + 0.000*"austra...
# 7     0.000*"semplicisti" + 0.000*"collettivisti" + ...
# 8     0.000*"azeff" + 0.000*"pablo" + 0.000*"unions"...
# 9     0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 10    0.000*"buggerru" + 0.000*"pronunciate" + 0.000...
# 11    0.001*"censura" + 0.001*"fanciulli" + 0.001*"a...
# 12    0.000*"collettivisti" + 0.000*"turner" + 0.000...
# Name: words, dtype: object
# nr of topics: 14
# 0     0.000*"ninfa" + 0.000*"egeria" + 0.000*"fata" ...
# 1     0.000*"rouanet" + 0.000*"bertoldo" + 0.000*"sc...
# 2     0.000*"montenegro" + 0.000*"magazine" + 0.000*...
# 3     0.001*"abarno" + 0.001*"polignani" + 0.000*"st...
# 4     0.001*"roosevelt" + 0.001*"contadini" + 0.001*...
# 5     0.000*"vaughan" + 0.000*"nasi" + 0.000*"quinta...
# 6     0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 7     0.001*"prigionieri" + 0.001*"alleati" + 0.001*...
# 8     0.001*"coal" + 0.001*"zucchero" + 0.001*"evere...
# 9     0.000*"collettivisti" + 0.000*"montpelier" + 0...
# 10    0.000*"serrati" + 0.000*"kotoku" + 0.000*"rela...
# 11    0.000*"dimostrata" + 0.000*"cercheranno" + 0.0...
# 12    0.001*"angelelli" + 0.000*"canevelli" + 0.000*...
# 13    0.000*"panie" + 0.000*"good" + 0.000*"merlino"...
# Name: words, dtype: object
# nr of topics: 15
# 0     0.000*"sessuale" + 0.000*"deviare" + 0.000*"go...
# 1     0.001*"partito" + 0.001*"anarchici" + 0.001*"s...
# 2     0.000*"ringraziamento" + 0.000*"sublimi" + 0.0...
# 3     0.001*"ferrer" + 0.001*"maggio" + 0.001*"pace"...
# 4     0.000*"tiremm" + 0.000*"collettivisti" + 0.000...
# 5     0.000*"max" + 0.000*"emanano" + 0.000*"gorki" ...
# 6     0.001*"francisco" + 0.001*"wilson" + 0.001*"fr...
# 7     0.000*"monroe" + 0.000*"kees" + 0.000*"dimessi...
# 8     0.000*"breen" + 0.000*"cacciatore" + 0.000*"lo...
# 9     0.000*"steunemberg" + 0.000*"calumet" + 0.000*...
# 10    0.000*"scalpellini" + 0.000*"marxisti" + 0.000...
# 11    0.000*"hillstrom" + 0.000*"inquisitore" + 0.00...
# 12    0.000*"hell" + 0.000*"bourges" + 0.000*"indece...
# 13    0.000*"robert" + 0.000*"hoover" + 0.000*"tagli...
# 14    0.000*"sopravvivenza" + 0.000*"rifanno" + 0.00...
# Name: words, dtype: object
# nr of topics: 16
# 0     0.001*"dagoes" + 0.000*"vassallaggio" + 0.000*...
# 1     0.001*"engels" + 0.000*"tagliati" + 0.000*"pen...
# 2     0.000*"biribi" + 0.000*"gohier" + 0.000*"consu...
# 3     0.000*"springfield" + 0.000*"trovai" + 0.000*"...
# 4     0.001*"masetti" + 0.001*"bocchini" + 0.001*"di...
# 5     0.001*"partito" + 0.001*"congresso" + 0.001*"c...
# 6     0.001*"pressed" + 0.001*"carco" + 0.001*"breen...
# 7     0.000*"schneider" + 0.000*"percorrere" + 0.000...
# 8     0.000*"vanini" + 0.000*"espulsi" + 0.000*"mand...
# 9     0.000*"travolta" + 0.000*"gallina" + 0.000*"pi...
# 10    0.001*"dio" + 0.001*"ferrer" + 0.001*"società"...
# 11    0.000*"penrose" + 0.000*"sidi" + 0.000*"dimmi"...
# 12    0.000*"udine" + 0.000*"pentimento" + 0.000*"gi...
# 13    0.001*"bertoni" + 0.000*"gohier" + 0.000*"minn...
# 14    0.000*"turner" + 0.000*"clarence" + 0.000*"pla...
# 15    0.000*"francis" + 0.000*"gambetta" + 0.000*"tr...
# Name: words, dtype: object
# nr of topics: 17
# 0     0.000*"tittoni" + 0.000*"laboratori" + 0.000*"...
# 1     0.000*"serajevo" + 0.000*"prive" + 0.000*"pola...
# 2     0.000*"combatterli" + 0.000*"rivoluzionano" + ...
# 3     0.000*"colajanni" + 0.000*"dieta" + 0.000*"ipe...
# 4     0.001*"giolitti" + 0.001*"kotoku" + 0.001*"dia...
# 5     0.000*"comporti" + 0.000*"priori" + 0.000*"ley...
# 6     0.000*"australia" + 0.000*"rintocco" + 0.000*"...
# 7     0.000*"mostravano" + 0.000*"vantato" + 0.000*"...
# 8     0.002*"ferrer" + 0.002*"lawrence" + 0.001*"gia...
# 9     0.001*"sciopero" + 0.001*"partito" + 0.001*"so...
# 10    0.001*"individualisti" + 0.000*"children" + 0....
# 11    0.001*"wilson" + 0.001*"liberale" + 0.001*"mes...
# 12    0.001*"polignani" + 0.001*"abarno" + 0.000*"al...
# 13    0.000*"cripple" + 0.000*"hell" + 0.000*"inesau...
# 14    0.000*"alaggio" + 0.000*"garcia" + 0.000*"tari...
# 15    0.001*"ghigliottina" + 0.001*"clericali" + 0.0...
# 16    0.000*"fata" + 0.000*"fitzgerald" + 0.000*"ane...
# Name: words, dtype: object
# nr of topics: 18
# 0     0.000*"ringraziamento" + 0.000*"vesti" + 0.000...
# 1     0.000*"tiremm" + 0.000*"ricovero" + 0.000*"par...
# 2     0.001*"partito" + 0.001*"socialista" + 0.001*"...
# 3     0.000*"carrozza" + 0.000*"furfanti" + 0.000*"c...
# 4     0.001*"scioperanti" + 0.001*"roosevelt" + 0.00...
# 5     0.001*"attwill" + 0.000*"salem" + 0.000*"pizzo...
# 6     0.001*"madero" + 0.001*"belga" + 0.001*"nottur...
# 7     0.000*"springfield" + 0.000*"liabeuf" + 0.000*...
# 8     0.001*"attwill" + 0.000*"reyes" + 0.000*"letti...
# 9     0.000*"sidi" + 0.000*"phoenix" + 0.000*"vanni"...
# 10    0.002*"bocchini" + 0.001*"falls" + 0.001*"long...
# 11    0.000*"great" + 0.000*"alieni" + 0.000*"good" ...
# 12    0.001*"acciarito" + 0.001*"scalpellini" + 0.00...
# 13    0.000*"fornai" + 0.000*"verre" + 0.000*"blanda...
# 14    0.000*"montenegro" + 0.000*"perù" + 0.000*"lot...
# 15    0.000*"moroni" + 0.000*"marinaio" + 0.000*"art...
# 16    0.000*"francis" + 0.000*"vaughan" + 0.000*"vie...
# 17    0.001*"diego" + 0.001*"agency" + 0.001*"citize...
# Name: words, dtype: object
# nr of topics: 19
# 0     0.001*"green" + 0.000*"chieste" + 0.000*"rumor...
# 1     0.000*"neebe" + 0.000*"distruggerla" + 0.000*"...
# 2     0.001*"wilson" + 0.001*"morti" + 0.001*"spagna...
# 3     0.000*"basa" + 0.000*"infranti" + 0.000*"gani"...
# 4     0.001*"bakounine" + 0.001*"sfruttati" + 0.001*...
# 5     0.001*"sciopero" + 0.001*"scioperanti" + 0.001...
# 6     0.001*"falcon" + 0.000*"mocrazia" + 0.000*"esc...
# 7     0.000*"diciasette" + 0.000*"derubare" + 0.000*...
# 8     0.000*"mooney" + 0.000*"untori" + 0.000*"succe...
# 9     0.001*"partito" + 0.001*"socialisti" + 0.001*"...
# 10    0.002*"tampa" + 0.001*"journal" + 0.001*"trova...
# 11    0.001*"bara" + 0.000*"crudelmente" + 0.000*"go...
# 12    0.002*"mooney" + 0.001*"cunha" + 0.001*"ficker...
# 13    0.000*"durevole" + 0.000*"inghiottito" + 0.000...
# 14    0.000*"tiremm" + 0.000*"mooney" + 0.000*"evere...
# 15    0.000*"howard" + 0.000*"onorata" + 0.000*"asce...
# 16    0.000*"hoover" + 0.000*"garfield" + 0.000*"con...
# 17    0.001*"sacro" + 0.001*"fiori" + 0.001*"labor" ...
# 18    0.001*"meunier" + 0.000*"tunisia" + 0.000*"ing...
# Name: words, dtype: object

# %%
# select the model to display the rest of the steps by typing the desired number of topics below
numtopics = 10

# %%
idx = models_idx.index(numtopics)
model = models[idx]

# %% [markdown]
# # Topic visualisation

# %% [markdown]
# ## Data Preparation

# %%
# !wget https://raw.githubusercontent.com/DHARPA-Project/TopicModelling-/master/vis-files/tm_1/jscode-test-2.js
# !wget https://raw.githubusercontent.com/DHARPA-Project/TopicModelling-/master/vis-files/tm_1/tm1_data_prepare_gensim.py
# Out:
# --2020-07-24 08:45:58--  https://raw.githubusercontent.com/DHARPA-Project/TopicModelling-/master/vis-files/tm_1/jscode-test-2.js
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219774 (215K) [text/plain]
# Saving to: ‘jscode-test-2.js’
#
# jscode-test-2.js    100%[===================>] 214.62K  --.-KB/s    in 0.04s
#
# 2020-07-24 08:45:58 (5.10 MB/s) - ‘jscode-test-2.js’ saved [219774/219774]
#
# --2020-07-24 08:45:59--  https://raw.githubusercontent.com/DHARPA-Project/TopicModelling-/master/vis-files/tm_1/tm1_data_prepare_gensim.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22824 (22K) [text/plain]
# Saving to: ‘tm1_data_prepare_gensim.py’
#
# tm1_data_prepare_ge 100%[===================>]  22.29K  --.-KB/s    in 0.01s
#
# 2020-07-24 08:45:59 (2.18 MB/s) - ‘tm1_data_prepare_gensim.py’ saved [22824/22824]

# %%
# %%capture
# !pip install funcy

# %%
# %run -i tm1_data_prepare_gensim

# %%
data_vis = prepare(model, corpus, id2word, doc_topic_dist=None)

# %%
topic_info = data_vis[1][data_vis[1]['Category'] == 'Default'].copy()

# %%
topic_info['relevance'] = ''

# %%
for i in range(numtopics):
  topic_num = i+1
  data = data_vis.sorted_terms(topic=topic_num, _lambda=.6).copy()
  topic_info = topic_info.append(data)

# %%
# uncomment to show the full output of a topic, replace 'Topic8' by the topic to display
# topic_info[topic_info['Category'] == 'Topic8']

# %%
topic_info.to_csv(output_folder + '/topic_info.csv')

# %%
topic_proportion = data_vis[0].copy()

# %%
topic_proportion['proportion'] = topic_proportion['Freq'] / 100

# %%
topic_proportion.index.name = 'topic_id'

# %%
topic_proportion.to_csv(output_folder + '/topic_proportion.csv')

# %%
# download also in Jupyter environment for further processing
topic_info.to_csv('topic_info.csv')
topic_proportion.to_csv('topic_proportion.csv')

# %%
# %%capture
import notebook.nbextensions
notebook.nbextensions.install_nbextension('topic_info.csv', user=True)
notebook.nbextensions.install_nbextension('topic_proportion.csv', user=True)

# %% [markdown]
# ## Visualisation

# %%
from IPython.display import display, HTML
from IPython.core.display import Javascript

# %%
# this version of the viz is not optimised for TFIDF but the fix will be applied on
# final version of the viz
display(HTML('<style>@import url("https://fonts.googleapis.com/css2?family=Fira+Sans:wght@300&display=swap");#vis_tm_1{width:40%; margin-left:20%}.svg-container{position:relative;width:100%;vertical-align:top;overflow:hidden;margin:0;padding:0;}.svg-content-responsive{margin:0;padding:0;display:inline-block;position:absolute;top:0;left:0}.line_style{stroke:"rgb(70, 130, 180,.3)";stroke-width:1}.svg_h1{font-size:.9em}.svg_h1,.svg_h2{font-family:"Fira Sans",Arial}.svg_h2{font-size:.6em}.svg_text{font-size:.8em}.svg_text,.svg_text_2{font-family:"Fira Sans",Arial}.svg_text_2{font-size:.7em}.svg_text_3{font-family:"Fira Sans";font-size:.6em}.select_box{width:30%;padding-left:1em;font-family:"Fira Sans",Arial}.select_box select{width:100%;background-color:#fff;padding:.5em .6em;box-shadow:inset 0 1px 3px #ddd;vertical-align:middle;font-family:"Fira Sans",Arial,sans-serif;letter-spacing:.01em;line-height:1.15;-webkit-writing-mode:horizontal-tb!important;text-rendering:auto;color:#000;letter-spacing:normal;word-spacing:normal;text-transform:none;text-indent:0;text-shadow:none;display:inline-block;text-align:start;-webkit-appearance:menulist;align-items:center;white-space:pre;-webkit-rtl-ordering:logical;background-color:#f8f8f8;cursor:default;margin:0;font:400 11px system-ui;border-radius:5px;border:1px solid #a6a6a6;border-image:none;border-image:initial}.select_box select:focus{border-color:#fff;outline:0;box-shadow:inset 0 1px 1px rgba(0,0,0,.075),0 0 1px rgba(102,175,233,.2)}</style>'))
display(HTML('<div id="vis_tm_1"></div>'))
Javascript(filename='jscode-test-2.js')
# Out:
# <style>@import url("https://fonts.googleapis.com/css2?family=Fira+Sans:wght@300&display=swap");#vis_tm_1{width:40%; margin-left:20%}.svg-container{position:relative;width:100%;vertical-align:top;overflow:hidden;margin:0;padding:0;}.svg-content-responsive{margin:0;padding:0;display:inline-block;position:absolute;top:0;left:0}.line_style{stroke:"rgb(70, 130, 180,.3)";stroke-width:1}.svg_h1{font-size:.9em}.svg_h1,.svg_h2{font-family:"Fira Sans",Arial}.svg_h2{font-size:.6em}.svg_text{font-size:.8em}.svg_text,.svg_text_2{font-family:"Fira Sans",Arial}.svg_text_2{font-size:.7em}.svg_text_3{font-family:"Fira Sans";font-size:.6em}.select_box{width:30%;padding-left:1em;font-family:"Fira Sans",Arial}.select_box select{width:100%;background-color:#fff;padding:.5em .6em;box-shadow:inset 0 1px 3px #ddd;vertical-align:middle;font-family:"Fira Sans",Arial,sans-serif;letter-spacing:.01em;line-height:1.15;-webkit-writing-mode:horizontal-tb!important;text-rendering:auto;color:#000;letter-spacing:normal;word-spacing:normal;text-transform:none;text-indent:0;text-shadow:none;display:inline-block;text-align:start;-webkit-appearance:menulist;align-items:center;white-space:pre;-webkit-rtl-ordering:logical;background-color:#f8f8f8;cursor:default;margin:0;font:400 11px system-ui;border-radius:5px;border:1px solid #a6a6a6;border-image:none;border-image:initial}.select_box select:focus{border-color:#fff;outline:0;box-shadow:inset 0 1px 1px rgba(0,0,0,.075),0 0 1px rgba(102,175,233,.2)}</style>
# <div id="vis_tm_1"></div>

# %% [markdown]
# # Topic distribution

# %% [markdown]
# ## 3.1. Distribution per topic and per document

# %%
# %%capture
ldamodel = model

# %%
doc_topic_weights = ldamodel.inference(corpus)[0]
doc_topic_dists = doc_topic_weights / doc_topic_weights.sum(axis=1)[:, None]

# %%
distribution = pd.DataFrame(doc_topic_dists,columns=[f'topic{i}' for i in range(numtopics)])

# %%
distribution.index.name = 'document'

# %%
# add file names and publication name
distribution_wfiles = distribution.copy()
distribution_wfiles.insert(0, 'document_path', corpus_df['file_name'])
distribution_wfiles.insert(1, 'publication_name', corpus_df['publication_name'])
distribution_wfiles
# Out:
#                                      document_path  ...    topic9
# document                                            ...
# 0         2012271201_1917-08-25_ed-1_seq-1_ocr.txt  ...  0.003886
# 1         2012271201_1905-01-21_ed-1_seq-1_ocr.txt  ...  0.004513
# 2         2012271201_1914-08-01_ed-1_seq-1_ocr.txt  ...  0.004292
# 3         2012271201_1910-04-09_ed-1_seq-1_ocr.txt  ...  0.004154
# 4         2012271201_1917-10-13_ed-1_seq-1_ocr.txt  ...  0.003916
# ...                                            ...  ...       ...
# 766       2012271201_1909-03-13_ed-1_seq-1_ocr.txt  ...  0.003983
# 767       2012271201_1917-08-04_ed-1_seq-1_ocr.txt  ...  0.004260
# 768       2012271201_1914-01-17_ed-1_seq-1_ocr.txt  ...  0.004470
# 769       2012271201_1908-09-26_ed-1_seq-1_ocr.txt  ...  0.005265
# 770       2012271201_1918-03-09_ed-1_seq-1_ocr.txt  ...  0.003971
#
# [771 rows x 12 columns]

# %% [markdown]
# ## 3.2. Distribution per topic for the whole corpus

# %%
corpus_df['doc_length'] = corpus_df['doc_prep_nostop'].apply(lambda x: len(x))

# %%
topic_frequency = distribution.mul(corpus_df['doc_length'], axis=0).sum()

# %%
topic_proportion = (topic_frequency / topic_frequency.sum()*100).sort_values(ascending=False)

# %%
topic_proportion
# Out:
# topic5    82.761601
# topic2    13.669364
# topic0     0.452379
# topic1     0.445237
# topic4     0.445237
# topic3     0.445237
# topic7     0.445237
# topic6     0.445237
# topic8     0.445237
# topic9     0.445237
# dtype: float64

# %%
# dataframe with values to sort them by order of importance
distribution_df = pd.DataFrame(topic_proportion, columns=['weight'])

# %%
distribution_df.index.name = "topics"

# %%
distribution_df.to_csv(output_folder + '/topic_distribution.csv')

# %%
topics = distribution_df.index.array

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
ax.barh(topics, distribution_df['weight'], align='center')
ax.set_xlabel('Weight (%)')
# Out:
# Text(0.5, 0, 'Weight (%)')

# %% [markdown]
# ### 3.3. Distribution per publication

# %%
import re
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
groupby2 = distribution_wfiles.copy()

# %%
distribution_title = groupby2.groupby(['publication_name']).mean().reset_index()
#distribution_title['publication'] = distribution_title['publication'].apply(lambda x: get_pub_name(x))

# %%
distribution_title
# Out:
#      publication_name    topic0    topic1  ...    topic7    topic8    topic9
# 0  Cronaca Sovversiva  0.004614  0.004555  ...  0.004555  0.004555  0.004555
#
# [1 rows x 11 columns]

# %%
distribution_title.to_csv(output_folder + '/distribution_per_publication.csv')

# %%
#restructuring df so that it can work with seaborn
df_vis2 = pd.DataFrame(columns=['publication', 'topic_id', 'distribution'])
x=0
columns_nr = len(distribution_title.columns)-1
for i in range(len(distribution_title)):
  for j in range(columns_nr):
    df_vis2.loc[x] = ''
    df_vis2['publication'].loc[x] = distribution_title['publication_name'].loc[i]
    df_vis2['topic_id'].loc[x] = distribution_title.columns[j+1]
    df_vis2['distribution'].loc[x] = distribution_title.iloc[i,(j+1)]
    x+= 1

# %%
df_vis2.pivot('publication','topic_id', 'distribution')\
.plot(kind='bar', stacked=True, colormap='Paired', 
      figsize=(2,4), title='Normalized proportions of topic weights per title.')\
.legend(bbox_to_anchor=(1.75, 1))

# %% [markdown]
# # Topics weight over time

# %% [markdown]
# ## 4.1 Aggregate document weights

# %%
# grouping data per month

# %%
distribution_wfiles['date'] = distribution_wfiles['document_path'].apply(lambda x: get_date(x))
distribution_wfiles['year'] = distribution_wfiles['document_path'].apply(lambda x: get_year(x))
distribution_wfiles['month'] = distribution_wfiles['document_path'].apply(lambda x: get_month(x))

# %%
groupby = distribution_wfiles.copy()

# %%
# drop columns that won't be needed at this stage
groupby = groupby.drop(['document_path', 'date'], axis=1)

# %%
# group by year 
distribution_year = groupby.groupby(['year']).mean().reset_index()

# %%
distribution_year
# Out:
#     year    topic0    topic1    topic2  ...    topic6    topic7    topic8    topic9
# 0   1903  0.004983  0.004983  0.129861  ...  0.004983  0.004983  0.004983  0.004983
# 1   1904  0.005088  0.005088  0.117718  ...  0.005088  0.005088  0.005088  0.005088
# 2   1905  0.005152  0.005152  0.122780  ...  0.005152  0.005152  0.005152  0.005152
# 3   1906  0.005347  0.005347  0.118963  ...  0.005347  0.005347  0.005347  0.005347
# 4   1907  0.005215  0.005215  0.118071  ...  0.005215  0.005215  0.005215  0.005215
# 5   1908  0.004625  0.004625  0.144587  ...  0.004625  0.004625  0.004625  0.004625
# 6   1909  0.005279  0.004391  0.127071  ...  0.004391  0.004391  0.004391  0.004391
# 7   1910  0.004152  0.004152  0.129361  ...  0.004152  0.004152  0.004152  0.004152
# 8   1911  0.004158  0.004158  0.139583  ...  0.004158  0.004158  0.004158  0.004158
# 9   1912  0.004319  0.004319  0.132557  ...  0.004319  0.004319  0.004319  0.004319
# 10  1913  0.004508  0.004508  0.135590  ...  0.004508  0.004508  0.004508  0.004508
# 11  1914  0.004135  0.004135  0.117798  ...  0.004135  0.004135  0.004135  0.004135
# 12  1915  0.004328  0.004328  0.149244  ...  0.004328  0.004328  0.004328  0.004328
# 13  1916  0.004115  0.004115  0.145548  ...  0.004115  0.004115  0.004115  0.004115
# 14  1917  0.004179  0.004179  0.170031  ...  0.004179  0.004179  0.004179  0.004179
# 15  1918  0.004143  0.004143  0.182976  ...  0.004143  0.004143  0.004143  0.004143
# 16  1919  0.003888  0.003888  0.161284  ...  0.003888  0.003888  0.003888  0.003888
#
# [17 rows x 11 columns]

# %%
distribution_year.to_csv(output_folder + '/distribution_per_year.csv')

# %% [markdown]
# ## 4.2 Yearly average of normalized weight per topic

# %% [markdown]
# ### 4.2.1. Line chart view

# %%
#restructuring df so that it can work with seaborn
df_vis = pd.DataFrame(columns=['time', 'topic_id', 'distribution'])
x=0
columns_nr = len(distribution_year.columns)-1
for i in range(len(distribution_year)):
  for j in range(columns_nr):
    df_vis.loc[x] = ''
    df_vis['time'].loc[x] = distribution_year['year'].loc[i]
    df_vis['topic_id'].loc[x] = distribution_year.columns[j+1]
    df_vis['distribution'].loc[x] = distribution_year.iloc[i,(j+1)]
    x+= 1

# %%
sns.factorplot(data= df_vis, 
               x= 'time',
               y= 'distribution',
               hue = 'topic_id',
               aspect=2,
               saturation=.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### 4.2.2. Bar chart view

# %%
sns.factorplot(data= df_vis, 
               x= 'time',
               y= 'distribution',
               kind= 'bar',
               hue = 'topic_id',
               aspect=2,
               saturation=.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### 4.2.3. Topic weights per title over time

# %%
groupby3 = distribution_wfiles.copy()

# %%
distribution_title_time = groupby3.groupby(['year','publication_name']).mean().reset_index()

# %%
distribution_title_time
# Out:
#     year    publication_name    topic0  ...    topic7    topic8    topic9
# 0   1903  Cronaca Sovversiva  0.004983  ...  0.004983  0.004983  0.004983
# 1   1904  Cronaca Sovversiva  0.005088  ...  0.005088  0.005088  0.005088
# 2   1905  Cronaca Sovversiva  0.005152  ...  0.005152  0.005152  0.005152
# 3   1906  Cronaca Sovversiva  0.005347  ...  0.005347  0.005347  0.005347
# 4   1907  Cronaca Sovversiva  0.005215  ...  0.005215  0.005215  0.005215
# 5   1908  Cronaca Sovversiva  0.004625  ...  0.004625  0.004625  0.004625
# 6   1909  Cronaca Sovversiva  0.005279  ...  0.004391  0.004391  0.004391
# 7   1910  Cronaca Sovversiva  0.004152  ...  0.004152  0.004152  0.004152
# 8   1911  Cronaca Sovversiva  0.004158  ...  0.004158  0.004158  0.004158
# 9   1912  Cronaca Sovversiva  0.004319  ...  0.004319  0.004319  0.004319
# 10  1913  Cronaca Sovversiva  0.004508  ...  0.004508  0.004508  0.004508
# 11  1914  Cronaca Sovversiva  0.004135  ...  0.004135  0.004135  0.004135
# 12  1915  Cronaca Sovversiva  0.004328  ...  0.004328  0.004328  0.004328
# 13  1916  Cronaca Sovversiva  0.004115  ...  0.004115  0.004115  0.004115
# 14  1917  Cronaca Sovversiva  0.004179  ...  0.004179  0.004179  0.004179
# 15  1918  Cronaca Sovversiva  0.004143  ...  0.004143  0.004143  0.004143
# 16  1919  Cronaca Sovversiva  0.003888  ...  0.003888  0.003888  0.003888
#
# [17 rows x 12 columns]

# %%
distribution_title_time.to_csv(output_folder + 'distribution_per_publication_over_time.csv')

# %% [markdown]
# ### 4.2.4. Rolling average

# %% [markdown]
# #### 4.2.4.1. Rolling average by topic

# %%
rolling_mean = distribution_year.rolling(2).mean()

# %%
rolling_mean.to_csv(output_folder + 'rolling_mean.csv')

# %%
#restructuring df so that it can work with seaborn
df_vis3 = pd.DataFrame(columns=['time', 'topic_id', 'rolling_mean'])
x=0
columns_nr = len(rolling_mean.columns)-1
for i in range(len(rolling_mean)):
  for j in range(columns_nr):
    if ( rolling_mean.iloc[i,(j+1)] > 0 ):
      df_vis3.loc[x] = ''
      df_vis3['time'].loc[x] = distribution_year['year'].loc[i]
      df_vis3['topic_id'].loc[x] = rolling_mean.columns[j+1]
      df_vis3['rolling_mean'].loc[x] = rolling_mean.iloc[i,(j+1)]
      x+= 1

# %%
df_vis3
# Out:
#      time topic_id rolling_mean
# 0    1904   topic0   0.00503517
# 1    1904   topic1   0.00503517
# 2    1904   topic2      0.12379
# 3    1904   topic3   0.00503517
# 4    1904   topic4   0.00503517
# ..    ...      ...          ...
# 155  1919   topic5     0.795748
# 156  1919   topic6   0.00401529
# 157  1919   topic7   0.00401529
# 158  1919   topic8   0.00401529
# 159  1919   topic9   0.00401529
#
# [160 rows x 3 columns]

# %%
sns.factorplot(data= df_vis3, 
               x= 'time',
               y= 'rolling_mean',
               hue = 'topic_id',
               aspect=2,
               saturation=.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### 4.2.4.1. Rolling average by publication

# %%
# Filtering the distribution over time by publication
# in the cell below replace 'Cronaca Sovversiva' by the publication to display
# and for the output file, each time the filter is applied on a publication, change the output file name

# %%
distribution_publication_time = distribution_title_time[distribution_title_time['publication_name'] == 'Cronaca Sovversiva']

# %%
rolling_mean_publication = distribution_publication_time.rolling(2).mean()

# %%
rolling_mean_publication.to_csv(output_folder + 'rolling_mean_cronaca_sovversiva.csv')

# %%
#restructuring df so that it can work with seaborn
df_vis4 = pd.DataFrame(columns=['time', 'topic_id', 'rolling_mean'])
x=0
columns_nr = len(rolling_mean_publication.columns)
for i in range(len(rolling_mean_publication)):
  for j in range(columns_nr):
    if ( rolling_mean_publication.iloc[i,(j)] > 0 ):
      df_vis4.loc[x] = ''
      df_vis4['time'].loc[x] = distribution_year['year'].loc[i]
      df_vis4['topic_id'].loc[x] = rolling_mean_publication.columns[j]
      df_vis4['rolling_mean'].loc[x] = rolling_mean_publication.iloc[i,(j)]
      x+= 1

# %%
df_vis4
# Out:
#      time topic_id rolling_mean
# 0    1904   topic0   0.00503517
# 1    1904   topic1   0.00503517
# 2    1904   topic2      0.12379
# 3    1904   topic3   0.00503517
# 4    1904   topic4   0.00503517
# ..    ...      ...          ...
# 155  1919   topic5     0.795748
# 156  1919   topic6   0.00401529
# 157  1919   topic7   0.00401529
# 158  1919   topic8   0.00401529
# 159  1919   topic9   0.00401529
#
# [160 rows x 3 columns]

# %%
sns.factorplot(data= df_vis4, 
               x= 'time',
               y= 'rolling_mean',
               hue = 'topic_id',
               aspect=2,
               saturation=.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
